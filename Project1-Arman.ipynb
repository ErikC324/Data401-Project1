# %%
# !pip install --user uszipcode;
from uszipcode import SearchEngine
import pandas as pd
import numpy as np

search = SearchEngine(simple_zipcode=True)
# may need to add slash before datasets
df = pd.read_csv('datasets/iowaliquor.csv').dropna()[['Date', 'County', 'Store Name', 'Zip Code', 'Sale (Dollars)']]
df.head()
# Out:
# Requirement already satisfied: uszipcode in c:\users\arman\appdata\roaming\python\python38\site-packages (0.2.4)
# Requirement already satisfied: sqlalchemy in c:\users\arman\appdata\roaming\python\python38\site-packages (from uszipcode) (1.3.19)
# Requirement already satisfied: pathlib-mate in c:\users\arman\appdata\roaming\python\python38\site-packages (from uszipcode) (1.0.0)
# Requirement already satisfied: attrs in c:\users\arman\appdata\local\programs\python\python38\lib\site-packages (from uszipcode) (19.3.0)
# Requirement already satisfied: requests in c:\users\arman\appdata\local\programs\python\python38\lib\site-packages (from uszipcode) (2.22.0)
# Requirement already satisfied: six in c:\users\arman\appdata\local\programs\python\python38\lib\site-packages (from pathlib-mate->uszipcode) (1.13.0)
# Requirement already satisfied: autopep8 in c:\users\arman\appdata\roaming\python\python38\site-packages (from pathlib-mate->uszipcode) (1.5.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\arman\appdata\local\programs\python\python38\lib\site-packages (from requests->uszipcode) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\arman\appdata\local\programs\python\python38\lib\site-packages (from requests->uszipcode) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\arman\appdata\local\programs\python\python38\lib\site-packages (from requests->uszipcode) (1.25.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arman\appdata\local\programs\python\python38\lib\site-packages (from requests->uszipcode) (2019.11.28)
# Requirement already satisfied: pycodestyle>=2.6.0 in c:\users\arman\appdata\roaming\python\python38\site-packages (from autopep8->pathlib-mate->uszipcode) (2.6.0)
# Requirement already satisfied: toml in c:\users\arman\appdata\roaming\python\python38\site-packages (from autopep8->pathlib-mate->uszipcode) (0.10.1)
# WARNING: You are using pip version 19.2.3, however version 20.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# c:\users\arman\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3050: DtypeWarning: Columns (6,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Date    County                            Store Name Zip Code  \
# 1  12/20/2014    Benton                        Roy's Foodland    52332
# 2  09/09/2013      Linn          Wal-Mart 1528 / Cedar Rapids    52402
# 3  12/12/2012     Mills  No Frills Supermarkets #803 / Glenwo    51534
# 4  10/14/2015  Woodbury        Hy-Vee Food Store / Sioux City    51106
# 5  05/08/2012       Lee     Sonny's Super Market / West Point    52656
#
#    Sale (Dollars)
# 1           27.66
# 2          134.76
# 3          495.60
# 4          121.56
# 5           40.29

# %% [markdown]
# ## 2016 Presidential Election Data

# %%
election = pd.read_csv('datasets/usa-2016-presidential-election-by-county.csv', sep=';')
election = election[['State', 'County', 'Less Than High School Diploma', 'At Least High School Diploma',
                    'At Least Bachelors\'s Degree', 'Graduate Degree', 'Median Earnings 2010',
                    'Children Under 6 Living in Poverty', 'Adults 65 and Older Living in Poverty',
                    'Preschool.Enrollment.Ratio.enrolled.ages.3.and.4', 'Gini.Coefficient',
                    'Service.occupations', 'Median Age', 'Poor.physical.health.days', 'Poor.mental.health.days',
                    'Low.birthweight', 'Teen.births', 'Children.in.single.parent.households', 'Adult.smoking',
                    'Adult.obesity', 'Diabetes', 'Uninsured', 'Unemployment',
                    'elevation', 'temp', 'precip']]

election = election[election['State'] == 'Iowa']
election['County'] = election['County'].str.split(' County,').str[0]
election = election.fillna(election.mean())
election.head()
# Out:
#     State      County  Less Than High School Diploma  \
# 63   Iowa        Tama                           11.9
# 90   Iowa  Des Moines                           10.3
# 127  Iowa      Howard                           13.2
# 140  Iowa    Mitchell                           10.4
# 177  Iowa      Monona                           12.4
#
#      At Least High School Diploma  At Least Bachelors's Degree  \
# 63                           88.1                         16.5
# 90                           89.7                         17.6
# 127                          86.8                         11.5
# 140                          89.6                         16.6
# 177                          87.6                         14.7
#
#      Graduate Degree  Median Earnings 2010  \
# 63               4.4          27001.761585
# 90               5.3          24628.303810
# 127              3.0          26203.329205
# 140              4.2          26460.248570
# 177              2.6          23500.104125
#
#      Children Under 6 Living in Poverty  \
# 63                                16.00
# 90                                23.25
# 127                               20.45
# 140                                3.60
# 177                               14.25
#
#      Adults 65 and Older Living in Poverty  \
# 63                                    7.85
# 90                                    6.30
# 127                                  18.35
# 140                                   8.35
# 177                                   7.10
#
#      Preschool.Enrollment.Ratio.enrolled.ages.3.and.4  ...  Teen.births  \
# 63                                               47.9  ...         37.8
# 90                                               38.0  ...         48.2
# 127                                              45.2  ...         27.6
# 140                                              29.4  ...         14.3
# 177                                              43.9  ...         22.5
#
#      Children.in.single.parent.households  Adult.smoking  Adult.obesity  \
# 63                                  0.372          0.179          0.289
# 90                                  0.332          0.208          0.323
# 127                                 0.210          0.110          0.298
# 140                                 0.189          0.146          0.274
# 177                                 0.349          0.170          0.274
#
#      Diabetes  Uninsured  Unemployment  elevation       temp    precip
# 63      0.108      0.138         0.066     278.00   8.991168  931.9260
# 90      0.118      0.097         0.064     210.90  11.666667  977.3920
# 127     0.089      0.118         0.052     382.50   6.722222  925.0680
# 140     0.086      0.107         0.048     351.90   8.991168  912.1140
# 177     0.096      0.117         0.071     361.95   8.991168  796.9885
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Combine Datasets

# %%
df = pd.merge(df, election, on='County')
print(df.isna().sum())
df.head()
# Out:
# Date                                                0
# County                                              0
# Store Name                                          0
# Zip Code                                            0
# Sale (Dollars)                                      0
# State                                               0
# Less Than High School Diploma                       0
# At Least High School Diploma                        0
# At Least Bachelors's Degree                         0
# Graduate Degree                                     0
# Median Earnings 2010                                0
# Children Under 6 Living in Poverty                  0
# Adults 65 and Older Living in Poverty               0
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4    0
# Gini.Coefficient                                    0
# Service.occupations                                 0
# Median Age                                          0
# Poor.physical.health.days                           0
# Poor.mental.health.days                             0
# Low.birthweight                                     0
# Teen.births                                         0
# Children.in.single.parent.households                0
# Adult.smoking                                       0
# Adult.obesity                                       0
# Diabetes                                            0
# Uninsured                                           0
# Unemployment                                        0
# elevation                                           0
# temp                                                0
# precip                                              0
# dtype: int64
#          Date  County                    Store Name Zip Code  Sale (Dollars)  \
# 0  12/20/2014  Benton                Roy's Foodland    52332           27.66
# 1  03/24/2015  Benton  Fareway Stores #462 / Vinton    52349           73.80
# 2  01/24/2013  Benton       Karam Kaur Khasriya Llc    52208           44.58
# 3  02/16/2012  Benton        Grieder Beverage Depot    52208          239.88
# 4  06/05/2013  Benton                Roy's Foodland    52332           16.50
#
#   State  Less Than High School Diploma  At Least High School Diploma  \
# 0  Iowa                            7.4                          92.6
# 1  Iowa                            7.4                          92.6
# 2  Iowa                            7.4                          92.6
# 3  Iowa                            7.4                          92.6
# 4  Iowa                            7.4                          92.6
#
#    At Least Bachelors's Degree  Graduate Degree  ...  Teen.births  \
# 0                         17.8              4.3  ...         19.1
# 1                         17.8              4.3  ...         19.1
# 2                         17.8              4.3  ...         19.1
# 3                         17.8              4.3  ...         19.1
# 4                         17.8              4.3  ...         19.1
#
#    Children.in.single.parent.households  Adult.smoking  Adult.obesity  \
# 0                                 0.235          0.223          0.297
# 1                                 0.235          0.223          0.297
# 2                                 0.235          0.223          0.297
# 3                                 0.235          0.223          0.297
# 4                                 0.235          0.223          0.297
#
#    Diabetes  Uninsured  Unemployment  elevation      temp  precip
# 0      0.09      0.092         0.053      259.1  9.333333  930.91
# 1      0.09      0.092         0.053      259.1  9.333333  930.91
# 2      0.09      0.092         0.053      259.1  9.333333  930.91
# 3      0.09      0.092         0.053      259.1  9.333333  930.91
# 4      0.09      0.092         0.053      259.1  9.333333  930.91
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Aggregate and Get Zip Code Statistics

# %%
df["YearMonth"] = df["Date"].str.split("/").str[2] + "-" + df["Date"].str.split("/").str[0]

totalSales = pd.DataFrame(df.groupby(["YearMonth", "Zip Code"]).sum())
totalSales.reset_index(inplace=True)
totalSales["Zip Code"] = totalSales["Zip Code"].replace("712-2", 51529)
totalSales["Zip Code"] = totalSales["Zip Code"].astype(int)

populationDict = {}
popDensityDict = {}
housingUnitsDict = {}
incomeDict = {}

for zc in totalSales["Zip Code"].unique():
    stats = search.by_zipcode(zc)
    populationDict[zc] = stats.population
    popDensityDict[zc] = stats.population_density
    housingUnitsDict[zc] = stats.housing_units
    incomeDict[zc] = stats.median_household_income

# %%
totalSales["Month"] = totalSales["YearMonth"].str.split("-").str[-1]
totalSales["Population"] = totalSales["Zip Code"].map(populationDict)
totalSales["PopulationDensity"] = totalSales["Zip Code"].map(popDensityDict)
totalSales["HousingUnits"] = totalSales["Zip Code"].map(housingUnitsDict)
totalSales["MedianIncome"] = totalSales["Zip Code"].map(incomeDict)
totalSales["SalesPerCapita"] = totalSales["Sale (Dollars)"] / totalSales["Population"]
totalSales["LogPopDensity"] = np.log(totalSales["PopulationDensity"])
totalSales.dropna(inplace=True)

# %%
totalSales.head()
# Out:
#   YearMonth  Zip Code  Sale (Dollars)  Less Than High School Diploma  \
# 0   2012-01     50010           59.52                            4.7
# 1   2012-01     50060           49.28                           15.6
# 2   2012-01     50138           27.55                            8.6
# 3   2012-01     50158          182.22                           14.3
# 4   2012-01     50201           12.30                            4.7
#
#    At Least High School Diploma  At Least Bachelors's Degree  Graduate Degree  \
# 0                          95.3                         47.2             19.3
# 1                          84.4                         10.8              2.5
# 2                          91.4                         24.0              7.3
# 3                          85.7                         18.7              5.7
# 4                          95.3                         47.2             19.3
#
#    Median Earnings 2010  Children Under 6 Living in Poverty  \
# 0          17362.730795                               11.75
# 1          22831.213970                               16.40
# 2          27009.609525                               13.05
# 3          27821.110160                               26.30
# 4          17362.730795                               11.75
#
#    Adults 65 and Older Living in Poverty  ...   elevation      temp  \
# 0                                   6.15  ...  298.833333  8.991168
# 1                                  11.95  ...  330.700000  9.944444
# 2                                   5.65  ...  255.250000  8.991168
# 3                                   6.45  ...  291.500000  8.991168
# 4                                   6.15  ...  298.833333  8.991168
#
#         precip  Month  Population  PopulationDensity  HousingUnits  \
# 0   900.853333     01     29359.0              490.0       13618.0
# 1  1039.114000     01      2507.0               14.0        1221.0
# 2   936.117000     01     11720.0               69.0        5241.0
# 3   905.425333     01     31591.0              149.0       12904.0
# 4   900.853333     01      8199.0               71.0        3559.0
#
#    MedianIncome  SalesPerCapita  LogPopDensity
# 0       48189.0        0.002027       6.194405
# 1       43226.0        0.019657       2.639057
# 2       49214.0        0.002351       4.234107
# 3       49767.0        0.005768       5.003946
# 4       56619.0        0.001500       4.262680
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Linear Regression

# %%
X = totalSales[['LogPopDensity', 'MedianIncome', 'Month']]
X = np.array(pd.get_dummies(X))
y = np.array(totalSales['SalesPerCapita'])

# %%
b = np.linalg.inv(X.T@X)@X.T@y

# %%
b
# Out:
# array([ 1.26839800e+00, -1.00232656e-04,  4.24859688e+00,  4.37212579e+00,
#         4.48309953e+00,  4.83324129e+00,  5.04504956e+00,  5.46507673e+00,
#         5.08374900e+00,  4.79072549e+00,  4.75796120e+00,  6.06773761e+00,
#         4.58303691e+00,  5.88980703e+00])

# %%
np.sqrt(((X@b - y)**2).mean())
# Out:
# 8.261998100568555
